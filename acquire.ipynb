# %% [markdown]
# ## Time Series Data Acquisition Exercises

# %%
# imports
import pandas as pd
import requests
import acquire

# %% [markdown]
# 1. Using the code from the lesson as a guide and the REST API from https://python.zach.lol/api/v1/items as we did in the lesson, create a dataframe named items that has all of the data for items.

# %%
items = acquire.get_items()
items.info()

# %% [markdown]
# 2. Do the same thing, but for stores (https://python.zach.lol/api/v1/stores)

# %%
stores = acquire.get_stores()
stores.info()

# %% [markdown]
# 3. Extract the data for sales (https://python.zach.lol/api/v1/sales). There are a lot of pages of data here, so your code will need to be a little more complex. Your code should continue fetching data from the next page until all of the data is extracted.

# %%
sales = acquire.get_sales()
sales.info()

# %% [markdown]
# 4. Save the data in your files to local csv files so that it will be faster to access in the future.

# %%
acquire.items_csv()

# %%
acquire.stores_csv()

# %%
acquire.sales_csv()

# %% [markdown]
# 5. Combine the data from your three separate dataframes into one large dataframe.

# %%
full_cart = acquire.all_groceries()
full_cart.info()

# %% [markdown]
# 6. Acquire the Open Power Systems Data for Germany, which has been rapidly expanding its renewable energy production in recent years. The data set includes country-wide totals of electricity consumption, wind power production, and solar power production for 2006-2017. You can get the data here: https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv

# %%
OPSD = acquire.get_opsd()
OPSD.info()

# %% [markdown]
# 7. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions in the acquire.py file and be able to re-run the functions and get the same data.

# %%
# Insert Check Mark Here

# %%
#Function to take in any csv and create a dataframe
def csv_to_dataframe(url, key1, key2=None):
    # Let's take an example url and make a get request
    response = requests.get(url)
    #create dictionary object
    data= response.json()
    if key2 != None:
        data_list = response.json()[key1][key2]
    else:
        data_list = response.json()[key1]
        df= pd.DataFrame(data_list)
    return df

# %%
# what if I only want to return a certain number of page results?

acquire.new_items_page_range(alpha=2, omega='ALL')
# Out:
#                 item_brand  item_id  \
# 0             Doctors Best       21
# 1            Betty Crocker       22
# 2                    Reese       23
# 3             Smart Living       24
# 4                     Hood       25
# 5                Triaminic       26
# 6                   Morton       27
# 7             Usda Produce       28
# 8                    Heinz       29
# 9                  Petmate       30
# 10        Zhenas Gypsy Tea       31
# 11                Barefoot       32
# 12         The First Years       33
# 13                   Halls       34
# 14             Natures Way       35
# 15  Deerfields Gluten Free       36
# 16                  Nakano       37
# 17        Sundown Naturals       38
# 18                Munchies       39
# 19                    Amys       40
# 20             P.f. Changs       41
# 21      Moms Best Naturals       42
# 22                 Ferrara       43
# 23                  Elmers       44
# 24                Kelloggs       45
# 25              Mama Marys       46
# 26              Bear Naked       47
# 27                    Dove       48
# 28                Easy-off       49
# 29                  Choice       50
#
#                                             item_name  item_price  \
# 0   Doctors Best Best Curcumin C3 Complex 1000mg T...        8.09
# 1   Betty Crocker Twin Pack Real Potatoes Scallope...        7.31
# 2      Reese Mandarin Oranges Segments In Light Syrup        1.78
# 3                 Smart Living Charcoal Lighter Fluid        5.34
# 4          Hood Latte Iced Coffee Drink Vanilla Latte        2.43
# 5   Triaminic Syrup Night Time Cold & Cough Grape 4oz        0.98
# 6                           Morton Kosher Salt Coarse        6.01
# 7                                               Guava        7.52
# 8                         Heinz Tomato Ketchup - 2 Ct        8.65
# 9   Petmate Booda Bones Steak Bacon & Chicken Flav...        8.39
# 10  Zhenas Gypsy Tea Herbal Red Tea Sachets Fire L...        4.21
# 11                         Barefoot Pinot Grigio  187        0.68
# 12  Tomy The First Years Gumdrop Orthodontic Pacif...        6.52
# 13  Halls Menthol Cough Suppresant/oral Anesthetic...        4.17
# 14                     Natures Way Forskohlii - 60 Ct        5.19
# 15           Rice Bran Gluten Free Dinner Rolls Plain        7.95
# 16              Nakano Seasoned Rice Vinegar Original        9.59
# 17  Sundown Naturals Essential Electrolytes Tropic...        3.45
# 18  Munchies Sandwich Crackers Cheddar Cheese On G...        9.02
# 19               Amys Light & Lean Spaghetti Italiano        0.60
# 20  P.f. Changs Home Menu Meal For Two Beef With B...        5.62
# 21  Moms Best Naturals Cereal Toasted Cinnamon Squ...        2.97
# 22                              Ferrara Vanilla Syrup        8.40
# 23                Elmers Board Mate Dual Tip Glue Pen        7.06
# 24                Kelloggs Disney Pixar Cars 2 Cereal        4.40
# 25                                        Pizza Sauce        4.65
# 26  Bear Naked Fit Almond Crisp 100 Percent Natura...        7.38
# 27  Dove Men + Care Antiperspirant Deodorant Cool ...        3.72
# 28                  Easy-off Oven Cleaner Lemon Scent        9.54
# 29  Choice Organic Teas Black Tea Classic Black - ...        5.20
#
#       item_upc12    item_upc14
# 0   753950001954  753950001954
# 1    16000288829   16000288829
# 2    70670009658   70670009658
# 3   688267084225  688267084225
# 4    44100117428   44100117428
# 5   300436344045  300436344045
# 6    24600017008   24600017008
# 7   719175900007  719175900007
# 8    13000001038   13000001038
# 9   723503568678  723503568678
# 10  652790100226  652790100226
# 11    8500004528    8500004528
# 12   71463060078   71463060078
# 13  312546628694  312546628694
# 14   33674100066   33674100066
# 15  610358991525  610358991525
# 16   73575295003   73575295003
# 17   30768540548   30768540548
# 18   28400029254   28400029254
# 19   42272008063   42272008063
# 20   31000670016   31000670016
# 21  883978129115  883978129115
# 22   71403000379   71403000379
# 23   26000001403   26000001403
# 24   38000542237   38000542237
# 25   35457770664   35457770664
# 26  884623708976  884623708976
# 27   79400271631   79400271631
# 28   62338879772   62338879772
# 29   47445919221   47445919221

# %%
acquire.get_items_page_range(alpha=2, omega='ALL')
# Out:
#                 item_brand  item_id  \
# 0             Doctors Best       21
# 1            Betty Crocker       22
# 2                    Reese       23
# 3             Smart Living       24
# 4                     Hood       25
# 5                Triaminic       26
# 6                   Morton       27
# 7             Usda Produce       28
# 8                    Heinz       29
# 9                  Petmate       30
# 10        Zhenas Gypsy Tea       31
# 11                Barefoot       32
# 12         The First Years       33
# 13                   Halls       34
# 14             Natures Way       35
# 15  Deerfields Gluten Free       36
# 16                  Nakano       37
# 17        Sundown Naturals       38
# 18                Munchies       39
# 19                    Amys       40
# 20             P.f. Changs       41
# 21      Moms Best Naturals       42
# 22                 Ferrara       43
# 23                  Elmers       44
# 24                Kelloggs       45
# 25              Mama Marys       46
# 26              Bear Naked       47
# 27                    Dove       48
# 28                Easy-off       49
# 29                  Choice       50
#
#                                             item_name  item_price  \
# 0   Doctors Best Best Curcumin C3 Complex 1000mg T...        8.09
# 1   Betty Crocker Twin Pack Real Potatoes Scallope...        7.31
# 2      Reese Mandarin Oranges Segments In Light Syrup        1.78
# 3                 Smart Living Charcoal Lighter Fluid        5.34
# 4          Hood Latte Iced Coffee Drink Vanilla Latte        2.43
# 5   Triaminic Syrup Night Time Cold & Cough Grape 4oz        0.98
# 6                           Morton Kosher Salt Coarse        6.01
# 7                                               Guava        7.52
# 8                         Heinz Tomato Ketchup - 2 Ct        8.65
# 9   Petmate Booda Bones Steak Bacon & Chicken Flav...        8.39
# 10  Zhenas Gypsy Tea Herbal Red Tea Sachets Fire L...        4.21
# 11                         Barefoot Pinot Grigio  187        0.68
# 12  Tomy The First Years Gumdrop Orthodontic Pacif...        6.52
# 13  Halls Menthol Cough Suppresant/oral Anesthetic...        4.17
# 14                     Natures Way Forskohlii - 60 Ct        5.19
# 15           Rice Bran Gluten Free Dinner Rolls Plain        7.95
# 16              Nakano Seasoned Rice Vinegar Original        9.59
# 17  Sundown Naturals Essential Electrolytes Tropic...        3.45
# 18  Munchies Sandwich Crackers Cheddar Cheese On G...        9.02
# 19               Amys Light & Lean Spaghetti Italiano        0.60
# 20  P.f. Changs Home Menu Meal For Two Beef With B...        5.62
# 21  Moms Best Naturals Cereal Toasted Cinnamon Squ...        2.97
# 22                              Ferrara Vanilla Syrup        8.40
# 23                Elmers Board Mate Dual Tip Glue Pen        7.06
# 24                Kelloggs Disney Pixar Cars 2 Cereal        4.40
# 25                                        Pizza Sauce        4.65
# 26  Bear Naked Fit Almond Crisp 100 Percent Natura...        7.38
# 27  Dove Men + Care Antiperspirant Deodorant Cool ...        3.72
# 28                  Easy-off Oven Cleaner Lemon Scent        9.54
# 29  Choice Organic Teas Black Tea Classic Black - ...        5.20
#
#       item_upc12    item_upc14
# 0   753950001954  753950001954
# 1    16000288829   16000288829
# 2    70670009658   70670009658
# 3   688267084225  688267084225
# 4    44100117428   44100117428
# 5   300436344045  300436344045
# 6    24600017008   24600017008
# 7   719175900007  719175900007
# 8    13000001038   13000001038
# 9   723503568678  723503568678
# 10  652790100226  652790100226
# 11    8500004528    8500004528
# 12   71463060078   71463060078
# 13  312546628694  312546628694
# 14   33674100066   33674100066
# 15  610358991525  610358991525
# 16   73575295003   73575295003
# 17   30768540548   30768540548
# 18   28400029254   28400029254
# 19   42272008063   42272008063
# 20   31000670016   31000670016
# 21  883978129115  883978129115
# 22   71403000379   71403000379
# 23   26000001403   26000001403
# 24   38000542237   38000542237
# 25   35457770664   35457770664
# 26  884623708976  884623708976
# 27   79400271631   79400271631
# 28   62338879772   62338879772
# 29   47445919221   47445919221
